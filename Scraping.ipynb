# %%
#import libraries:

from countries import countries_list
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import requests

import io
from PIL import Image
import numpy as np

downloads_directory = r"/home/alireza/Desktop/Banknotes/images"

# %%
# start a web driver to check what countries are available in the webpage:

list_of_available_countries = []        #empty list of countries

options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument("--headless")



prefs = {
    "download.default_directory": downloads_directory,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True
}
options.add_experimental_option("prefs", prefs)

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Open a webpage
driver.get("https://www.banknoteworld.com/banknotes/Banknotes-by-Country/?filter_bjeu3kfrd7=Banknote&filter_1vrzi848n7=Non-Graded&filter_5ammzleauo=United%20States%20of%20America")  


for country in countries_list:
    page_text = driver.page_source

    # country to search:
    search_word = country[1]

    # Check if the word is in the page text
    if search_word in page_text:
        print(f"The word '{search_word}' was found on the page.")
        list_of_available_countries.append(search_word)
    else:
        print(f"The word '{search_word}' was not found on the page.")

    # Close the WebDriver
driver.quit()
# Out:
# The word 'United States of America' was found on the page.
# The word 'Afghanistan' was found on the page.
# The word 'Albania' was found on the page.
# The word 'Algeria' was found on the page.
# The word 'American Samoa' was not found on the page.
# The word 'Andorra' was not found on the page.
# The word 'Angola' was found on the page.
# The word 'Anguilla' was not found on the page.
# The word 'Antarctica' was not found on the page.
# The word 'Antigua And Barbuda' was not found on the page.
# The word 'Argentina' was found on the page.
# The word 'Armenia' was found on the page.
# The word 'Aruba' was found on the page.
# The word 'Australia' was found on the page.
# The word 'Austria' was found on the page.
# The word 'Azerbaijan' was found on the page.
# The word 'Bahamas' was found on the page.
# The word 'Bahrain' was found on the page.
# The word 'Bangladesh' was found on the page.
# The word 'Barbados' was found on the page.
# The word 'Belarus' was found on the page.
# ...

# %%
#dictionary for all the images urls per country
dict_urls = {}

# %%
from utilities import *

# %%
for country in list_of_available_countries: 
    options = Options()
    #options.add_argument("--no-sandbox")
    #options.add_argument("--disable-dev-shm-usage")
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument("--headless")

    prefs = {
        "download.default_directory": downloads_directory,
        "download.prompt_for_download": False,
        "download.directory_upgrade": True
    }
    options.add_experimental_option("prefs", prefs)

    wd = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

    dict_urls[country] = get_images_from_webpage(wd, 1, 100, country)
# Out:
# Found images of United States of America 5
# Found images of United States of America 5
# Found images of United States of America 5
# Found images of United States of America 5
# Found images of United States of America 5
# Found images of United States of America 5
# Found images of United States of America 5
# No new items added in the last 6.0 seconds. Stopping the process.
# Found images of Afghanistan 2
# Found images of Afghanistan 2
# Found images of Afghanistan 2
# Found images of Afghanistan 2
# Found images of Afghanistan 2
# Found images of Afghanistan 2
# Found images of Afghanistan 2
# No new items added in the last 6.0 seconds. Stopping the process.
# Found images of Albania 7
# Found images of Albania 7
# Found images of Albania 7
# Found images of Albania 7
# Found images of Albania 7
# Found images of Albania 7
# Found images of Albania 7
# No new items added in the last 6.0 seconds. Stopping the process.
# Found images of Algeria 1
# Found images of Algeria 1
# ...

# %%
dict_urls.keys()
# Out:
# dict_keys(['United States of America', 'Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Bermuda', 'Bhutan', 'Bolivia', 'Botswana', 'Brazil', 'Bulgaria', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Kyrgyzstan', 'Laos', 'La
# ...

# %%
for country in dict_urls.keys():
    directory = downloads_directory + "/"+ country.replace(" ", "_")
    # !mkdir {directory}
    for i, url in enumerate(dict_urls[country]):
        print(f"Donwloading country {country}", f"Image number {i}")
        download_image(directory, url, "/"+str(i)+".jpg")
# Out:
# Donwloading country United States of America Image number 0
# Success
# Donwloading country United States of America Image number 1
# Success
# Donwloading country United States of America Image number 2
# Success
# Donwloading country United States of America Image number 3
# Success
# Donwloading country United States of America Image number 4
# Success
# Donwloading country Afghanistan Image number 0
# Success
# Donwloading country Afghanistan Image number 1
# Success
# Donwloading country Albania Image number 0
# Success
# Donwloading country Albania Image number 1
# Success
# Donwloading country Albania Image number 2
# Success
# Donwloading country Albania Image number 3
# Success
# Donwloading country Albania Image number 4
# Success
# Donwloading country Albania Image number 5
# Success
# Donwloading country Albania Image number 6
# Success
# Donwloading country Algeria Image number 0
# Success
# Donwloading country Angola Image number 0
# Success
# ...

# %%
for country in dict_urls.keys():
    if country == "United States of America":
        directory = downloads_directory + "/"+country
        # !mkdir {directory}
        for i, url in enumerate(dict_urls[country]):
            print(f"Donwloading country {country}", f"Image number {i}")
            download_image(directory, url, "/"+str(i)+".jpg")
# Out:
# Donwloading country United States of America Image number 0
# Failed - [Errno 2] No such file or directory: '/home/alireza/Desktop/Banknotes/images/United States of America/0.jpg'
# Donwloading country United States of America Image number 1
# Failed - [Errno 2] No such file or directory: '/home/alireza/Desktop/Banknotes/images/United States of America/1.jpg'
# Donwloading country United States of America Image number 2
# Failed - [Errno 2] No such file or directory: '/home/alireza/Desktop/Banknotes/images/United States of America/2.jpg'
# Donwloading country United States of America Image number 3
# Failed - [Errno 2] No such file or directory: '/home/alireza/Desktop/Banknotes/images/United States of America/3.jpg'
# Donwloading country United States of America Image number 4
# Failed - [Errno 2] No such file or directory: '/home/alireza/Desktop/Banknotes/images/United States of America/4.jpg'

# %%
country = "United States of America"

print(country)
# Out:
# United_States_of_America

# %%
# !mkdir {downloads_directory +"/"+"Afghanistan"}
directory = downloads_directory +"/"+"Afghanistan"
for i, url in enumerate(dict_urls["Afghanistan"]):
    download_image(directory, url, "/"+str(i)+".jpg")
# Out:
# mkdir: cannot create directory ‘/home/alireza/Desktop/Banknotes/images/Afghanistan’: File exists
# Success
# Success

# %%
downloads_directory
# Out:
# '/home/alireza/Desktop/Banknotes/images'

# %%
for i in dict_urls.keys():
    print(i)
# Out:
# United States of America
# Afghanistan
# Albania
# Algeria
# Angola
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Bermuda
# Bhutan
# Bolivia
# Botswana
# Brazil
# Bulgaria
# Burundi
# Cambodia
# Cameroon
# Canada
# Cape Verde
# Cayman Islands
# Chad
# Chile
# China
# Colombia
# Comoros
# Congo
# Cook Islands
# Costa Rica
# Croatia
# Cyprus
# Czech Republic
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Ecuador
# Egypt
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Fiji
# Finland
# France
# French Polynesia
# Gabon
# Gambia
# Georgia
# Germany
# Ghana
# Gibraltar
# Greece
# Guatemala
# Guinea
# Guyana
# Haiti
# Honduras
# Hong Kong
# Hungary
# Iceland
# India
# Indonesia
# Iraq
# Ireland
# Israel
# Italy
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Kenya
# Kuwait
# Kyrgyzstan
# Laos
# Latvia
# Lebanon
# Lesotho
# Liberia
# Libya
# Luxembourg
# Macau
# Macedonia
# Madagascar
# ...
